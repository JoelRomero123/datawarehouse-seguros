# %% [markdown]
# <a href="https://colab.research.google.com/github/JoelRomero123/datawarehouse-seguros/blob/main/Clientes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url="https://raw.githubusercontent.com/JoelRomero123/datawarehouse-seguros/refs/heads/main/data/clientes.csv"

# %% [markdown]
# BLOQUE 1:CARGA DEL DATASET

# %%
import pandas as pd

# %%
df=pd.read_csv(url)
# Out:
# Data set cargado corretamente

# %%
#LECTURA DEL ARCHIVO
display(df.head())
# Out:
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
#
#       genero fecha_nacimiento          ciudad segmento
# 0     Hombre       2011/11/24       SanMiguel      NaN
# 1        NaN         01-02-80        Sta. Ana      NaN
# 2  Masculino         06-18-79       S. Miguel      NaN
# 3  Masculino       1960-09-29      LaLibertad  REGULAR
# 4        NaN       1945/08/02   San Salvador      Pyme

# %% [markdown]
# BLOQUE 2: EXPLORACION DEL DATA SET

# %%
print("primeras filas del dataset")
display(df.head())
# Out:
# primeras filas del dataset
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
#
#       genero fecha_nacimiento          ciudad segmento
# 0     Hombre       2011/11/24       SanMiguel      NaN
# 1        NaN         01-02-80        Sta. Ana      NaN
# 2  Masculino         06-18-79       S. Miguel      NaN
# 3  Masculino       1960-09-29      LaLibertad  REGULAR
# 4        NaN       1945/08/02   San Salvador      Pyme

# %%
print("Dimensiones del dataset(filas,columnas)")
print(df.shape)
# Out:
# Dimensiones del dataset(filas,columnas)
# (3030, 7)

# %%
print("Nombres de las columnas")
print(df.columns)
# Out:
# Nombres de las columnas
# Index(['id_cliente', 'nombre', 'email', 'genero', 'fecha_nacimiento', 'ciudad',
#        'segmento'],
#       dtype='object')

# %%
print("Tipos de datos de las columnas")
print(df.dtypes)
# Out:
# Tipos de datos de las columnas
# id_cliente           int64
# nombre              object
# email               object
# genero              object
# fecha_nacimiento    object
# ciudad              object
# segmento            object
# dtype: object

# %%
print("valores nulos por columna")
print(df.isnull().sum())
# Out:
# valores nulos por columna
# id_cliente            0
# nombre                0
# email                 0
# genero              595
# fecha_nacimiento      0
# ciudad                0
# segmento            597
# dtype: int64

# %%
print("Registros duplicados")
print(df.duplicated().sum())
#
# Out:
# Registros duplicados
# 0

# %% [markdown]
# BLOQUE 3: LIMPIEZA DE DATOS

# %%
#ELIMINAR ESPACIOS AL INICIO Y AL FINAL EN COLUMNAS DE TEXTO
for col in df.select_dtypes(include=['object']):
    df[col] = df[col].str.strip()

# %%
#Normalizar el nombre
df["nombre"]=df["nombre"].str.title()

# %%
#Normalizar el email
df["email"]=df["email"].str.lower()

# %%
#Normalizar genero
df["genero"]=df["genero"].str.upper()

# %%
df['fecha_nacimiento'] = pd.to_datetime(df['fecha_nacimiento'], errors='coerce')

# %%
#Normalizar ciudad
df['ciudad']=df['ciudad'].str.title()
#limpieza de segmento
df['ciudad']=df["ciudad"].astype(str)
df['ciudad']=df["ciudad"].str.strip()
df['ciudad']=df["ciudad"].str.upper()

# %%
#limpieza de segmento
df['segmento']=df["segmento"].astype(str)
df['segmento']=df["segmento"].str.strip()
df['segmento']=df["segmento"].str.upper()

# %% [markdown]
# BLOQUE 4: VALIDACION DE DATOS

# %%
 df["MOTIVO DE RECHAZO"]= ""
 df.loc[df['id_cliente']],pd.isnull,isnull()
